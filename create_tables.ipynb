# %%
import psycopg2
import pandas as pd
from sql_queries import drop_table_queries, create_table_queries

# %%
def create_database():
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=root")
    conn.set_session(autocommit=True)
    cur = conn.cursor()

    # create sparkify database with UTF8 encoding
    cur.execute("DROP DATABASE accounts")
    cur.execute("CREATE DATABASE accounts")

    # close connection to default database
    conn.close()

    # connect to sparkify database
    conn = psycopg2.connect("host=127.0.0.1 dbname=accounts user=postgres password=root")
    cur = conn.cursor()

    return cur, conn

# %%
def drop_tables(cur, conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()

# %%
def create_tables(cur, conn):
    for query in create_table_queries:
        cur.execute(query)
        conn.commit()

# %%
AccountsCountry = pd.read_csv("data/Wealth-AccountsCountry.csv")

# %%
AccountsCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# 2                                    2020 (expected)
# 3                                               2016
# 4  2011. Population figures compiled from adminis...
#
#                       Latest household survey  \
# 0      Demographic and Health Survey, 2017/18
# 1  Multiple Indicator Cluster Survey, 2019/20
# 2      Demographic and Health Survey, 2015/16
# 3                                         NaN
# 4                                         NaN
#
#                                        Special Notes  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3  Fiscal year end: June 30; reporting period for...  ...
# 4  A simple multiplier is used to convert the nat...  ...
#
#    Source of most recent Income and expenditure data  \
# 0  Living Standards Measurement Study Survey (LSM...
# 1            Integrated household survey (IHS), 2016
# 2            Integrated household survey (IHS), 2016
# 3     Expenditure survey/budget survey (ES/BS), 2010
# 4                           Income survey (IS), 2015
#
#    Vital registration complete Latest agricultural census  \
# 0                          Yes                       2012
# 1                          Yes                       2008
# 2                          Yes                       2014
# 3                          Yes                  2015-2016
# 4                          Yes                       2010
#
#   Latest industrial data Latest trade data Latest water withdrawal data  \
# 0                 2013.0            2018.0                       2006.0
# 1                 2002.0            2018.0                       2011.0
# 2                    NaN            2018.0                       2012.0
# 3                 2013.0            2018.0                       2013.0
# 4                 2014.0            2018.0                       2010.0
#
#   2-alpha code WB-2 code Table Name Short Name
# 0           AL        AL    Albania    Albania
# 1           AR        AR  Argentina  Argentina
# 2           AM        AM    Armenia    Armenia
# 3           AU        AU  Australia  Australia
# 4           AT        AT    Austria    Austria
#
# [5 rows x 31 columns]

# %%
AccountsCountry.describe()
# Out:
#        National accounts reference year  Latest industrial data  \
# count                         59.000000              128.000000
# mean                        2012.847458             2007.664062
# std                            3.912022                8.918950
# min                         2000.000000             1973.000000
# 25%                         2010.000000             2005.750000
# 50%                         2015.000000             2012.000000
# 75%                         2015.000000             2013.000000
# max                         2019.000000             2014.000000
#
#        Latest trade data  Latest water withdrawal data
# count         142.000000                    140.000000
# mean         2017.140845                   2006.935714
# std             2.781886                      4.988059
# min          1995.000000                   1975.000000
# 25%          2017.000000                   2005.000000
# 50%          2018.000000                   2007.000000
# 75%          2018.000000                   2010.000000
# max          2018.000000                   2016.000000

# %%
AccountsCountry.columns
# Out:
# Index(['Code', 'Long Name', 'Income Group', 'Region', 'Lending category',
#        'Other groups', 'Currency Unit', 'Latest population census',
#        'Latest household survey', 'Special Notes',
#        'National accounts base year', 'National accounts reference year',
#        'System of National Accounts', 'SNA price valuation',
#        'Alternative conversion factor', 'PPP survey years',
#        'Balance of Payments Manual in use', 'External debt Reporting status',
#        'System of trade', 'Government Accounting concept',
#        'IMF data dissemination standard',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', '2-alpha code', 'WB-2 code',
#        'Table Name', 'Short Name'],
#       dtype='object')

# %%
null_count = AccountsCountry.isnull().sum()
null_count
# Out:
# Code                                                    5
# Long Name                                               3
# Income Group                                            4
# Region                                               7451
# Lending category                                     7490
# Other groups                                         7545
# Currency Unit                                        7451
# Latest population census                             7452
# Latest household survey                              7478
# Special Notes                                        7552
# National accounts base year                          7451
# National accounts reference year                     7538
# System of National Accounts                          7451
# SNA price valuation                                  7451
# Alternative conversion factor                        7556
# PPP survey years                                     7459
# Balance of Payments Manual in use                    7452
# External debt Reporting status                       7502
# System of trade                                      7462
# Government Accounting concept                        7471
# IMF data dissemination standard                      7452
# Source of most recent Income and expenditure data    7459
# Vital registration complete                          7524
# Latest agricultural census                           7492
# Latest industrial data                               7469
# Latest trade data                                    7455
# Latest water withdrawal data                         7457
# 2-alpha code                                         7452
# WB-2 code                                            7452
# Table Name                                           7451
# Short Name                                           7451
# dtype: int64

# %%
nan_count = AccountsCountry.isna().sum()
nan_count
# Out:
# Code                                                    5
# Long Name                                               3
# Income Group                                            4
# Region                                               7451
# Lending category                                     7490
# Other groups                                         7545
# Currency Unit                                        7451
# Latest population census                             7452
# Latest household survey                              7478
# Special Notes                                        7552
# National accounts base year                          7451
# National accounts reference year                     7538
# System of National Accounts                          7451
# SNA price valuation                                  7451
# Alternative conversion factor                        7556
# PPP survey years                                     7459
# Balance of Payments Manual in use                    7452
# External debt Reporting status                       7502
# System of trade                                      7462
# Government Accounting concept                        7471
# IMF data dissemination standard                      7452
# Source of most recent Income and expenditure data    7459
# Vital registration complete                          7524
# Latest agricultural census                           7492
# Latest industrial data                               7469
# Latest trade data                                    7455
# Latest water withdrawal data                         7457
# 2-alpha code                                         7452
# WB-2 code                                            7452
# Table Name                                           7451
# Short Name                                           7451
# dtype: int64

# %%
AccountsCountry_clean = AccountsCountry[['Code', 'Short Name', 'Table Name', 'Long Name', 'Currency Unit']]

# %%
AccountsCountry_clean.head()
# Out:
# shape: (5, 5)
# ┌──────┬────────────┬────────────┬───────────────────────────┬───────────────────┐
# │ Code ┆ Short Name ┆ Table Name ┆ Long Name                 ┆ Currency Unit     │
# │ ---  ┆ ---        ┆ ---        ┆ ---                       ┆ ---               │
# │ str  ┆ str        ┆ str        ┆ str                       ┆ str               │
# ╞══════╪════════════╪════════════╪═══════════════════════════╪═══════════════════╡
# │ ALB  ┆ Albania    ┆ Albania    ┆ Republic of Albania       ┆ Albanian lek      │
# │ ARG  ┆ Argentina  ┆ Argentina  ┆ Argentine Republic        ┆ Argentine peso    │
# │ ARM  ┆ Armenia    ┆ Armenia    ┆ Republic of Armenia       ┆ Armenian dram     │
# │ AUS  ┆ Australia  ┆ Australia  ┆ Commonwealth of Australia ┆ Australian dollar │
# │ AUT  ┆ Austria    ┆ Austria    ┆ Republic of Austria       ┆ Euro              │
# └──────┴────────────┴────────────┴───────────────────────────┴───────────────────┘

# %%
AccountsData = pd.read_csv("data/Wealth-AccountData.csv")

# %%
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# 4      4893.006      4737.857      4059.321      4191.445      4536.972
#
#   2000 [YR2000]  ... 2009 [YR2009] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 0      4.36E+10  ...  6.610000e+10  6.810000e+10  6.850000e+10  7.080000e+10
# 1      14118.13  ...  2.258200e+04  2.336286e+04  2.359058e+04  2.439397e+04
# 2      3424.007  ...  2.825336e+03  2.889150e+03  2.848523e+03  2.930234e+03
# 3      6872.019  ...  1.525319e+04  1.578992e+04  1.579854e+04  1.647360e+04
# 4      4695.071  ...  3.529144e+03  3.613606e+03  3.603694e+03  3.683810e+03
#
#    2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# 0   7.160000e+10   7.250000e+10   7.370000e+10       7.57E+10       7.80E+10
# 1   2.473162e+04   2.509002e+04   2.559371e+04       26326.26       27160.86
# 2   2.954273e+03   2.957420e+03   2.987545e+03       3072.504       3178.417
# 3   1.681013e+04   1.699138e+04   1.730701e+04        17817.1       18445.94
# 4   3.696744e+03   3.719608e+03   3.767628e+03       3872.142       3992.188
#
#    2018 [YR2018]
# 0       8.12E+10
# 1       28333.68
# 2       3312.927
# 3       19245.19
# 4       4161.137
#
# [5 rows x 28 columns]

# %%
AccountsData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
AccountsData_null_count = AccountsData.isnull().sum()
AccountsData_null_count
# Out:
# Country Name     0
# Country Code     0
# Series Name      0
# Series Code      0
# 1995 [YR1995]    0
# 1996 [YR1996]    0
# 1997 [YR1997]    0
# 1998 [YR1998]    0
# 1999 [YR1999]    0
# 2000 [YR2000]    0
# 2001 [YR2001]    0
# 2002 [YR2002]    0
# 2003 [YR2003]    0
# 2004 [YR2004]    0
# 2005 [YR2005]    0
# 2006 [YR2006]    0
# 2007 [YR2007]    0
# 2008 [YR2008]    0
# 2009 [YR2009]    0
# 2010 [YR2010]    0
# 2011 [YR2011]    0
# 2012 [YR2012]    0
# 2013 [YR2013]    0
# 2014 [YR2014]    0
# 2015 [YR2015]    0
# 2016 [YR2016]    0
# 2017 [YR2017]    0
# 2018 [YR2018]    0
# dtype: int64

# %%
AccountsSeries = pd.read_csv("data/Wealth-AccountSeries.csv")

# %%
AccountsSeries
# Out:
#               Code                                     Indicator Name  \
# 0        NW.HCA.TO                  Human capital (constant 2018 US$)
# 1        NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2   NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3   NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4   NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
# 5   NW.HCA.MALE.PC  Human capital per capita, male (constant 2018 ...
# 6   NW.HCA.FSEM.PC  Human capital per capita, self-employed female...
# 7   NW.HCA.MSEM.PC  Human capital per capita, self-employed male (...
# 8   NW.HCA.FEMP.TO  Human capital, employed female (constant 2018 ...
# 9   NW.HCA.MEMP.TO   Human capital, employed male (constant 2018 US$)
# 10  NW.HCA.FEMA.TO          Human capital, female (constant 2018 US$)
# 11  NW.HCA.MALE.TO            Human capital, male (constant 2018 US$)
# 12  NW.HCA.FSEM.TO  Human capital, self-employed female (constant ...
# 13  NW.HCA.MSEM.TO  Human capital, self-employed male (constant 20...
# 14       NW.NCA.TO                Natural capital (constant 2018 US$)
# 15       NW.NCA.PC     Natural capital per capita (constant 2018 US$)
# 16  NW.NCA.AGRI.PC  Natural capital per capita, agricultural land ...
# 17  NW.NCA.CROL.PC  Natural capital per capita, agricultural land:...
# 18  NW.NCA.PASL.PC  Natural capital per capita, agricultural land:...
# 19  NW.NCA.FISH.PC  Natural capital per capita, fisheries (constan...
# 20  NW.NCA.FECO.PC  Natural capital per capita, forests: ecosystem...
# 21  NW.NCA.FTIM.PC  Natural capital per capita, forests: timber (c...
# 22  NW.NCA.FOSL.PC  Natural capital per capita, fossil fuels (cons...
# 23  NW.NCA.MANG.PC  Natural capital per capita, mangroves (constan...
# 24  NW.NCA.SSOI.PC  Natural capital per capita, nonrenewable asset...
# 25  NW.NCA.SACO.PC  Natural capital per capita, nonrenewable asset...
# 26  NW.NCA.SAGA.PC  Natural capital per capita, nonrenewable asset...
# 27  NW.NCA.MINR.PC  Natural capital per capita, nonrenewable asset...
# 28  NW.NCA.SAOI.PC  Natural capital per capita, nonrenewable asset...
# 29  NW.NCA.PRAR.PC  Natural capital per capita, protected areas (c...
# 30  NW.NCA.RNEW.PC  Natural capital per capita, renewable (constan...
# 31  NW.NCA.AGRI.TO  Natural capital, agricultural land (constant 2...
# 32  NW.NCA.CROL.TO  Natural capital, agricultural land: cropland (...
# 33  NW.NCA.PASL.TO  Natural capital, agricultural land: pasturelan...
# 34  NW.NCA.FISH.TO     Natural capital, fisheries (constant 2018 US$)
# 35  NW.NCA.FECO.TO  Natural capital, forests: ecosystem services (...
# 36  NW.NCA.FTIM.TO  Natural capital, forests: timber (constant 201...
# 37  NW.NCA.FOSL.TO  Natural capital, fossil fuels (constant 2018 US$)
# 38  NW.NCA.MANG.TO     Natural capital, mangroves (constant 2018 US$)
# 39  NW.NCA.SSOI.TO  Natural capital, nonrenewable assets (constant...
# 40  NW.NCA.SACO.TO  Natural capital, nonrenewable assets: coal (co...
# 41  NW.NCA.SAGA.TO  Natural capital, nonrenewable assets: gas (con...
# 42  NW.NCA.MINR.TO  Natural capital, nonrenewable assets: minerals...
# 43  NW.NCA.SAOI.TO  Natural capital, nonrenewable assets: oil (con...
# 44  NW.NCA.PRAR.TO  Natural capital, protected areas (constant 201...
# 45  NW.NCA.RNEW.TO     Natural capital, renewable (constant 2018 US$)
# 46       NW.NFA.TO             Net foreign assets (constant 2018 US$)
# 47       NW.NFA.PC  Net foreign assets per capita (constant 2018 US$)
# 48       NW.PCA.TO               Produced capital (constant 2018 US$)
# 49       NW.PCA.PC    Produced capital per capita (constant 2018 US$)
# 50       NW.TOW.TO                   Total wealth (constant 2018 US$)
# 51       NW.TOW.PC        Total wealth per capita (constant 2018 US$)
#
#                                       Long definition  \
# 0   Human capital is computed as the present value...
# 1   Human capital is computed as the present value...
# 2   Human capital is computed as the present value...
# 3   Human capital is computed as the present value...
# 4   Human capital is computed as the present value...
# 5   Human capital is computed as the present value...
# 6   Human capital is computed as the present value...
# 7   Human capital is computed as the present value...
# 8   Human capital is computed as the present value...
# 9   Human capital is computed as the present value...
# 10  Human capital is computed as the present value...
# 11  Human capital is computed as the present value...
# 12  Human capital is computed as the present value...
# 13  Human capital is computed as the present value...
# 14  Natural capital includes the valuation of rene...
# 15  Natural capital includes the valuation of rene...
# 16  Natural capital includes the valuation of rene...
# 17  Natural capital includes the valuation of rene...
# 18  Natural capital includes the valuation of rene...
# 19  Natural capital includes the valuation of rene...
# 20  Natural capital includes the valuation of rene...
# 21  Natural capital includes the valuation of rene...
# 22  Natural capital includes the valuation of rene...
# 23  Natural capital includes the valuation of rene...
# 24  Natural capital includes the valuation of rene...
# 25  Natural capital includes the valuation of rene...
# 26  Natural capital includes the valuation of rene...
# 27  Natural capital includes the valuation of rene...
# 28  Natural capital includes the valuation of rene...
# 29  Natural capital includes the valuation of rene...
# 30  Natural capital includes the valuation of rene...
# 31  Natural capital includes the valuation of rene...
# 32  Natural capital includes the valuation of rene...
# 33  Natural capital includes the valuation of rene...
# 34  Natural capital includes the valuation of rene...
# 35  Natural capital includes the valuation of rene...
# 36  Natural capital includes the valuation of rene...
# 37  Natural capital includes the valuation of rene...
# 38  Natural capital includes the valuation of rene...
# 39  Natural capital includes the valuation of rene...
# 40  Natural capital includes the valuation of rene...
# 41  Natural capital includes the valuation of rene...
# 42  Natural capital includes the valuation of rene...
# 43  Natural capital includes the valuation of rene...
# 44  Natural capital includes the valuation of rene...
# 45  Natural capital includes the valuation of rene...
# 46  Net foreign assets is foreign assets minus for...
# 47  Net foreign assets is foreign assets minus for...
# 48  Produced capital includes the value of machine...
# 49  Produced capital includes the value of machine...
# 50  Total wealth is calculated as the sum of produ...
# 51  Total wealth is calculated as the sum of produ...
#
#                                                Source               Topic  \
# 0   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 1   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 2   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 3   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 4   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 5   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 6   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 7   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 8   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 9   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 10  World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 11  World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 12  World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 13  World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 14  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 15  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 16  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 17  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 18  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 19  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 20  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 21  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 22  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 23  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 24  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 25  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 26  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 27  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 28  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 29  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 30  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 31  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 32  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 33  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 34  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 35  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 36  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 37  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 38  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 39  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 40  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 41  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 42  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 43  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 44  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 45  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 46  World Bank. 2021. The Changing Wealth of Natio...  Net foreign assets
# 47  World Bank. 2021. The Changing Wealth of Natio...  Net foreign assets
# 48  World Bank. 2021. The Changing Wealth of Natio...    Produced capital
# 49  World Bank. 2021. The Changing Wealth of Natio...    Produced capital
# 50  World Bank. 2021. The Changing Wealth of Natio...        Total wealth
# 51  World Bank. 2021. The Changing Wealth of Natio...        Total wealth
#
#       Unit of measure Periodicity Reference period  \
# 0   Constant 2018 US$      Annual        1995-2018
# 1   Constant 2018 US$      Annual        1995-2018
# 2   Constant 2018 US$      Annual        1995-2018
# 3   Constant 2018 US$      Annual        1995-2018
# 4   Constant 2018 US$      Annual        1995-2018
# 5   Constant 2018 US$      Annual        1995-2018
# 6   Constant 2018 US$      Annual        1995-2018
# 7   Constant 2018 US$      Annual        1995-2018
# 8   Constant 2018 US$      Annual        1995-2018
# 9   Constant 2018 US$      Annual        1995-2018
# 10  Constant 2018 US$      Annual        1995-2018
# 11  Constant 2018 US$      Annual        1995-2018
# 12  Constant 2018 US$      Annual        1995-2018
# 13  Constant 2018 US$      Annual        1995-2018
# 14  Constant 2018 US$      Annual        1995-2018
# 15  Constant 2018 US$      Annual        1995-2018
# 16  Constant 2018 US$      Annual        1995-2018
# 17  Constant 2018 US$      Annual        1995-2018
# 18  Constant 2018 US$      Annual        1995-2018
# 19  Constant 2018 US$      Annual        1995-2018
# 20  Constant 2018 US$      Annual        1995-2018
# 21  Constant 2018 US$      Annual        1995-2018
# 22  Constant 2018 US$      Annual        1995-2018
# 23  Constant 2018 US$      Annual        1995-2018
# 24  Constant 2018 US$      Annual        1995-2018
# 25  Constant 2018 US$      Annual        1995-2018
# 26  Constant 2018 US$      Annual        1995-2018
# 27  Constant 2018 US$      Annual        1995-2018
# 28  Constant 2018 US$      Annual        1995-2018
# 29  Constant 2018 US$      Annual        1995-2018
# 30  Constant 2018 US$      Annual        1995-2018
# 31  Constant 2018 US$      Annual        1995-2018
# 32  Constant 2018 US$      Annual        1995-2018
# 33  Constant 2018 US$      Annual        1995-2018
# 34  Constant 2018 US$      Annual        1995-2018
# 35  Constant 2018 US$      Annual        1995-2018
# 36  Constant 2018 US$      Annual        1995-2018
# 37  Constant 2018 US$      Annual        1995-2018
# 38  Constant 2018 US$      Annual        1995-2018
# 39  Constant 2018 US$      Annual        1995-2018
# 40  Constant 2018 US$      Annual        1995-2018
# 41  Constant 2018 US$      Annual        1995-2018
# 42  Constant 2018 US$      Annual        1995-2018
# 43  Constant 2018 US$      Annual        1995-2018
# 44  Constant 2018 US$      Annual        1995-2018
# 45  Constant 2018 US$      Annual        1995-2018
# 46  Constant 2018 US$      Annual        1995-2018
# 47  Constant 2018 US$      Annual        1995-2018
# 48  Constant 2018 US$      Annual        1995-2018
# 49  Constant 2018 US$      Annual        1995-2018
# 50  Constant 2018 US$      Annual        1995-2018
# 51  Constant 2018 US$      Annual        1995-2018
#
#                   Statistical concept and methodology Previous Indicator Code  \
# 0   Total wealth is calculated by summing up estim...                     NaN
# 1   Total wealth is calculated by summing up estim...                     NaN
# 2   Total wealth is calculated by summing up estim...                     NaN
# 3   Total wealth is calculated by summing up estim...                     NaN
# 4   Total wealth is calculated by summing up estim...                     NaN
# 5   Total wealth is calculated by summing up estim...                     NaN
# 6   Total wealth is calculated by summing up estim...                     NaN
# 7   Total wealth is calculated by summing up estim...                     NaN
# 8   Total wealth is calculated by summing up estim...                     NaN
# 9   Total wealth is calculated by summing up estim...                     NaN
# 10  Total wealth is calculated by summing up estim...                     NaN
# 11  Total wealth is calculated by summing up estim...                     NaN
# 12  Total wealth is calculated by summing up estim...                     NaN
# 13  Total wealth is calculated by summing up estim...                     NaN
# 14  Total wealth is calculated by summing up estim...                     NaN
# 15  Total wealth is calculated by summing up estim...                     NaN
# 16  Total wealth is calculated by summing up estim...                     NaN
# 17  Total wealth is calculated by summing up estim...                     NaN
# 18  Total wealth is calculated by summing up estim...                     NaN
# 19  Total wealth is calculated by summing up estim...                     NaN
# 20  Total wealth is calculated by summing up estim...          NW.NCA.FNTI.PC
# 21  Total wealth is calculated by summing up estim...                     NaN
# 22  Total wealth is calculated by summing up estim...                     NaN
# 23  Total wealth is calculated by summing up estim...                     NaN
# 24  Total wealth is calculated by summing up estim...                     NaN
# 25  Total wealth is calculated by summing up estim...                     NaN
# 26  Total wealth is calculated by summing up estim...                     NaN
# 27  Total wealth is calculated by summing up estim...                     NaN
# 28  Total wealth is calculated by summing up estim...                     NaN
# 29  Total wealth is calculated by summing up estim...                     NaN
# 30  Total wealth is calculated by summing up estim...                     NaN
# 31  Total wealth is calculated by summing up estim...                     NaN
# 32  Total wealth is calculated by summing up estim...                     NaN
# 33  Total wealth is calculated by summing up estim...                     NaN
# 34  Total wealth is calculated by summing up estim...                     NaN
# 35  Total wealth is calculated by summing up estim...          NW.NCA.FNTI.TO
# 36  Total wealth is calculated by summing up estim...                     NaN
# 37  Total wealth is calculated by summing up estim...                     NaN
# 38  Total wealth is calculated by summing up estim...                     NaN
# 39  Total wealth is calculated by summing up estim...                     NaN
# 40  Total wealth is calculated by summing up estim...                     NaN
# 41  Total wealth is calculated by summing up estim...                     NaN
# 42  Total wealth is calculated by summing up estim...                     NaN
# 43  Total wealth is calculated by summing up estim...                     NaN
# 44  Total wealth is calculated by summing up estim...                     NaN
# 45  Total wealth is calculated by summing up estim...                     NaN
# 46  Total wealth is calculated by summing up estim...                     NaN
# 47  Total wealth is calculated by summing up estim...                     NaN
# 48  Total wealth is calculated by summing up estim...                     NaN
# 49  Total wealth is calculated by summing up estim...                     NaN
# 50  Total wealth is calculated by summing up estim...                     NaN
# 51  Total wealth is calculated by summing up estim...                     NaN
#
#                               Previous Indicator Name
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  Natural capital per capita, forests: nontimber...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  Natural capital, forests: nontimber (constant ...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN

# %%
AccountSeries_null_count = AccountsSeries.isnull().sum()
AccountSeries_null_count
# Out:
# Code                                    0
# Indicator Name                          0
# Long definition                         0
# Source                                  0
# Topic                                   0
# Unit of measure                         0
# Periodicity                             0
# Reference period                        0
# Statistical concept and methodology     0
# Previous Indicator Code                50
# Previous Indicator Name                50
# dtype: int64

# %%
AccountsSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 2  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 3  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 4  World Bank. 2021. The Changing Wealth of Natio...  Human capital
#
#      Unit of measure Periodicity Reference period  \
# 0  Constant 2018 US$      Annual        1995-2018
# 1  Constant 2018 US$      Annual        1995-2018
# 2  Constant 2018 US$      Annual        1995-2018
# 3  Constant 2018 US$      Annual        1995-2018
# 4  Constant 2018 US$      Annual        1995-2018
#
#                  Statistical concept and methodology Previous Indicator Code  \
# 0  Total wealth is calculated by summing up estim...                     NaN
# 1  Total wealth is calculated by summing up estim...                     NaN
# 2  Total wealth is calculated by summing up estim...                     NaN
# 3  Total wealth is calculated by summing up estim...                     NaN
# 4  Total wealth is calculated by summing up estim...                     NaN
#
#   Previous Indicator Name
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
AccountsSeries_clean = AccountsSeries[['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic', 'Unit of measure', 'Periodicity', 'Reference period', 'Statistical concept and methodology']]
AccountsSeries_clean
# Out:
#               Code                                     Indicator Name  \
# 0        NW.HCA.TO                  Human capital (constant 2018 US$)
# 1        NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2   NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3   NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4   NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
# 5   NW.HCA.MALE.PC  Human capital per capita, male (constant 2018 ...
# 6   NW.HCA.FSEM.PC  Human capital per capita, self-employed female...
# 7   NW.HCA.MSEM.PC  Human capital per capita, self-employed male (...
# 8   NW.HCA.FEMP.TO  Human capital, employed female (constant 2018 ...
# 9   NW.HCA.MEMP.TO   Human capital, employed male (constant 2018 US$)
# 10  NW.HCA.FEMA.TO          Human capital, female (constant 2018 US$)
# 11  NW.HCA.MALE.TO            Human capital, male (constant 2018 US$)
# 12  NW.HCA.FSEM.TO  Human capital, self-employed female (constant ...
# 13  NW.HCA.MSEM.TO  Human capital, self-employed male (constant 20...
# 14       NW.NCA.TO                Natural capital (constant 2018 US$)
# 15       NW.NCA.PC     Natural capital per capita (constant 2018 US$)
# 16  NW.NCA.AGRI.PC  Natural capital per capita, agricultural land ...
# 17  NW.NCA.CROL.PC  Natural capital per capita, agricultural land:...
# 18  NW.NCA.PASL.PC  Natural capital per capita, agricultural land:...
# 19  NW.NCA.FISH.PC  Natural capital per capita, fisheries (constan...
# 20  NW.NCA.FECO.PC  Natural capital per capita, forests: ecosystem...
# 21  NW.NCA.FTIM.PC  Natural capital per capita, forests: timber (c...
# 22  NW.NCA.FOSL.PC  Natural capital per capita, fossil fuels (cons...
# 23  NW.NCA.MANG.PC  Natural capital per capita, mangroves (constan...
# 24  NW.NCA.SSOI.PC  Natural capital per capita, nonrenewable asset...
# 25  NW.NCA.SACO.PC  Natural capital per capita, nonrenewable asset...
# 26  NW.NCA.SAGA.PC  Natural capital per capita, nonrenewable asset...
# 27  NW.NCA.MINR.PC  Natural capital per capita, nonrenewable asset...
# 28  NW.NCA.SAOI.PC  Natural capital per capita, nonrenewable asset...
# 29  NW.NCA.PRAR.PC  Natural capital per capita, protected areas (c...
# 30  NW.NCA.RNEW.PC  Natural capital per capita, renewable (constan...
# 31  NW.NCA.AGRI.TO  Natural capital, agricultural land (constant 2...
# 32  NW.NCA.CROL.TO  Natural capital, agricultural land: cropland (...
# 33  NW.NCA.PASL.TO  Natural capital, agricultural land: pasturelan...
# 34  NW.NCA.FISH.TO     Natural capital, fisheries (constant 2018 US$)
# 35  NW.NCA.FECO.TO  Natural capital, forests: ecosystem services (...
# 36  NW.NCA.FTIM.TO  Natural capital, forests: timber (constant 201...
# 37  NW.NCA.FOSL.TO  Natural capital, fossil fuels (constant 2018 US$)
# 38  NW.NCA.MANG.TO     Natural capital, mangroves (constant 2018 US$)
# 39  NW.NCA.SSOI.TO  Natural capital, nonrenewable assets (constant...
# 40  NW.NCA.SACO.TO  Natural capital, nonrenewable assets: coal (co...
# 41  NW.NCA.SAGA.TO  Natural capital, nonrenewable assets: gas (con...
# 42  NW.NCA.MINR.TO  Natural capital, nonrenewable assets: minerals...
# 43  NW.NCA.SAOI.TO  Natural capital, nonrenewable assets: oil (con...
# 44  NW.NCA.PRAR.TO  Natural capital, protected areas (constant 201...
# 45  NW.NCA.RNEW.TO     Natural capital, renewable (constant 2018 US$)
# 46       NW.NFA.TO             Net foreign assets (constant 2018 US$)
# 47       NW.NFA.PC  Net foreign assets per capita (constant 2018 US$)
# 48       NW.PCA.TO               Produced capital (constant 2018 US$)
# 49       NW.PCA.PC    Produced capital per capita (constant 2018 US$)
# 50       NW.TOW.TO                   Total wealth (constant 2018 US$)
# 51       NW.TOW.PC        Total wealth per capita (constant 2018 US$)
#
#                                       Long definition  \
# 0   Human capital is computed as the present value...
# 1   Human capital is computed as the present value...
# 2   Human capital is computed as the present value...
# 3   Human capital is computed as the present value...
# 4   Human capital is computed as the present value...
# 5   Human capital is computed as the present value...
# 6   Human capital is computed as the present value...
# 7   Human capital is computed as the present value...
# 8   Human capital is computed as the present value...
# 9   Human capital is computed as the present value...
# 10  Human capital is computed as the present value...
# 11  Human capital is computed as the present value...
# 12  Human capital is computed as the present value...
# 13  Human capital is computed as the present value...
# 14  Natural capital includes the valuation of rene...
# 15  Natural capital includes the valuation of rene...
# 16  Natural capital includes the valuation of rene...
# 17  Natural capital includes the valuation of rene...
# 18  Natural capital includes the valuation of rene...
# 19  Natural capital includes the valuation of rene...
# 20  Natural capital includes the valuation of rene...
# 21  Natural capital includes the valuation of rene...
# 22  Natural capital includes the valuation of rene...
# 23  Natural capital includes the valuation of rene...
# 24  Natural capital includes the valuation of rene...
# 25  Natural capital includes the valuation of rene...
# 26  Natural capital includes the valuation of rene...
# 27  Natural capital includes the valuation of rene...
# 28  Natural capital includes the valuation of rene...
# 29  Natural capital includes the valuation of rene...
# 30  Natural capital includes the valuation of rene...
# 31  Natural capital includes the valuation of rene...
# 32  Natural capital includes the valuation of rene...
# 33  Natural capital includes the valuation of rene...
# 34  Natural capital includes the valuation of rene...
# 35  Natural capital includes the valuation of rene...
# 36  Natural capital includes the valuation of rene...
# 37  Natural capital includes the valuation of rene...
# 38  Natural capital includes the valuation of rene...
# 39  Natural capital includes the valuation of rene...
# 40  Natural capital includes the valuation of rene...
# 41  Natural capital includes the valuation of rene...
# 42  Natural capital includes the valuation of rene...
# 43  Natural capital includes the valuation of rene...
# 44  Natural capital includes the valuation of rene...
# 45  Natural capital includes the valuation of rene...
# 46  Net foreign assets is foreign assets minus for...
# 47  Net foreign assets is foreign assets minus for...
# 48  Produced capital includes the value of machine...
# 49  Produced capital includes the value of machine...
# 50  Total wealth is calculated as the sum of produ...
# 51  Total wealth is calculated as the sum of produ...
#
#                                                Source               Topic  \
# 0   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 1   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 2   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 3   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 4   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 5   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 6   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 7   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 8   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 9   World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 10  World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 11  World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 12  World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 13  World Bank. 2021. The Changing Wealth of Natio...       Human capital
# 14  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 15  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 16  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 17  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 18  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 19  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 20  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 21  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 22  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 23  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 24  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 25  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 26  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 27  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 28  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 29  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 30  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 31  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 32  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 33  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 34  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 35  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 36  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 37  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 38  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 39  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 40  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 41  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 42  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 43  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 44  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 45  World Bank. 2021. The Changing Wealth of Natio...     Natural capital
# 46  World Bank. 2021. The Changing Wealth of Natio...  Net foreign assets
# 47  World Bank. 2021. The Changing Wealth of Natio...  Net foreign assets
# 48  World Bank. 2021. The Changing Wealth of Natio...    Produced capital
# 49  World Bank. 2021. The Changing Wealth of Natio...    Produced capital
# 50  World Bank. 2021. The Changing Wealth of Natio...        Total wealth
# 51  World Bank. 2021. The Changing Wealth of Natio...        Total wealth
#
#       Unit of measure Periodicity Reference period  \
# 0   Constant 2018 US$      Annual        1995-2018
# 1   Constant 2018 US$      Annual        1995-2018
# 2   Constant 2018 US$      Annual        1995-2018
# 3   Constant 2018 US$      Annual        1995-2018
# 4   Constant 2018 US$      Annual        1995-2018
# 5   Constant 2018 US$      Annual        1995-2018
# 6   Constant 2018 US$      Annual        1995-2018
# 7   Constant 2018 US$      Annual        1995-2018
# 8   Constant 2018 US$      Annual        1995-2018
# 9   Constant 2018 US$      Annual        1995-2018
# 10  Constant 2018 US$      Annual        1995-2018
# 11  Constant 2018 US$      Annual        1995-2018
# 12  Constant 2018 US$      Annual        1995-2018
# 13  Constant 2018 US$      Annual        1995-2018
# 14  Constant 2018 US$      Annual        1995-2018
# 15  Constant 2018 US$      Annual        1995-2018
# 16  Constant 2018 US$      Annual        1995-2018
# 17  Constant 2018 US$      Annual        1995-2018
# 18  Constant 2018 US$      Annual        1995-2018
# 19  Constant 2018 US$      Annual        1995-2018
# 20  Constant 2018 US$      Annual        1995-2018
# 21  Constant 2018 US$      Annual        1995-2018
# 22  Constant 2018 US$      Annual        1995-2018
# 23  Constant 2018 US$      Annual        1995-2018
# 24  Constant 2018 US$      Annual        1995-2018
# 25  Constant 2018 US$      Annual        1995-2018
# 26  Constant 2018 US$      Annual        1995-2018
# 27  Constant 2018 US$      Annual        1995-2018
# 28  Constant 2018 US$      Annual        1995-2018
# 29  Constant 2018 US$      Annual        1995-2018
# 30  Constant 2018 US$      Annual        1995-2018
# 31  Constant 2018 US$      Annual        1995-2018
# 32  Constant 2018 US$      Annual        1995-2018
# 33  Constant 2018 US$      Annual        1995-2018
# 34  Constant 2018 US$      Annual        1995-2018
# 35  Constant 2018 US$      Annual        1995-2018
# 36  Constant 2018 US$      Annual        1995-2018
# 37  Constant 2018 US$      Annual        1995-2018
# 38  Constant 2018 US$      Annual        1995-2018
# 39  Constant 2018 US$      Annual        1995-2018
# 40  Constant 2018 US$      Annual        1995-2018
# 41  Constant 2018 US$      Annual        1995-2018
# 42  Constant 2018 US$      Annual        1995-2018
# 43  Constant 2018 US$      Annual        1995-2018
# 44  Constant 2018 US$      Annual        1995-2018
# 45  Constant 2018 US$      Annual        1995-2018
# 46  Constant 2018 US$      Annual        1995-2018
# 47  Constant 2018 US$      Annual        1995-2018
# 48  Constant 2018 US$      Annual        1995-2018
# 49  Constant 2018 US$      Annual        1995-2018
# 50  Constant 2018 US$      Annual        1995-2018
# 51  Constant 2018 US$      Annual        1995-2018
#
#                   Statistical concept and methodology
# 0   Total wealth is calculated by summing up estim...
# 1   Total wealth is calculated by summing up estim...
# 2   Total wealth is calculated by summing up estim...
# 3   Total wealth is calculated by summing up estim...
# 4   Total wealth is calculated by summing up estim...
# 5   Total wealth is calculated by summing up estim...
# 6   Total wealth is calculated by summing up estim...
# 7   Total wealth is calculated by summing up estim...
# 8   Total wealth is calculated by summing up estim...
# 9   Total wealth is calculated by summing up estim...
# 10  Total wealth is calculated by summing up estim...
# 11  Total wealth is calculated by summing up estim...
# 12  Total wealth is calculated by summing up estim...
# 13  Total wealth is calculated by summing up estim...
# 14  Total wealth is calculated by summing up estim...
# 15  Total wealth is calculated by summing up estim...
# 16  Total wealth is calculated by summing up estim...
# 17  Total wealth is calculated by summing up estim...
# 18  Total wealth is calculated by summing up estim...
# 19  Total wealth is calculated by summing up estim...
# 20  Total wealth is calculated by summing up estim...
# 21  Total wealth is calculated by summing up estim...
# 22  Total wealth is calculated by summing up estim...
# 23  Total wealth is calculated by summing up estim...
# 24  Total wealth is calculated by summing up estim...
# 25  Total wealth is calculated by summing up estim...
# 26  Total wealth is calculated by summing up estim...
# 27  Total wealth is calculated by summing up estim...
# 28  Total wealth is calculated by summing up estim...
# 29  Total wealth is calculated by summing up estim...
# 30  Total wealth is calculated by summing up estim...
# 31  Total wealth is calculated by summing up estim...
# 32  Total wealth is calculated by summing up estim...
# 33  Total wealth is calculated by summing up estim...
# 34  Total wealth is calculated by summing up estim...
# 35  Total wealth is calculated by summing up estim...
# 36  Total wealth is calculated by summing up estim...
# 37  Total wealth is calculated by summing up estim...
# 38  Total wealth is calculated by summing up estim...
# 39  Total wealth is calculated by summing up estim...
# 40  Total wealth is calculated by summing up estim...
# 41  Total wealth is calculated by summing up estim...
# 42  Total wealth is calculated by summing up estim...
# 43  Total wealth is calculated by summing up estim...
# 44  Total wealth is calculated by summing up estim...
# 45  Total wealth is calculated by summing up estim...
# 46  Total wealth is calculated by summing up estim...
# 47  Total wealth is calculated by summing up estim...
# 48  Total wealth is calculated by summing up estim...
# 49  Total wealth is calculated by summing up estim...
# 50  Total wealth is calculated by summing up estim...
# 51  Total wealth is calculated by summing up estim...
